# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('../data/2-8-2022,12:9.csv')

# %%
df.shape
# Out:
# (6823, 31)

# %%
df.isnull().sum()
# Out:
# user_id                0
# id                     0
# uri                    0
# title                  0
# price                  0
# content               97
# imgs                 624
# refresh                0
# category               0
# beds                   0
# livings                2
# wc                     0
# area                 177
# type                6812
# street_width         213
# age                  744
# last_update            0
# street_direction    6800
# ketchen               19
# ac                    20
# furnished             47
# location               0
# path                   0
# user                   0
# native              6823
# rent_period            0
# city                   0
# district               0
# width               2245
# length              2245
# advertiser_type      220
# create_time            0
# __typename             0
# dtype: int64

# %%
msno.matrix(df, labels=True, filter="bottom", sort="ascending", n=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# type , street_direction  : have lots of nulls
#
# imgs : 624 null (lots of times to provided)
#
# content : 97 null (not provided)
#
# area : 177
#
# age : 744
#
# width    2245 null
#
# length    2245 null
#
# advertiser_type : 220
#
#
# the rest are ok
